# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Data/20200401-WHO.csv')
df
# Out:
#        Country/Territory  Total Confirmed  New Cases  Total Deaths  \
# 0                  China            82631         86          3321
# 1      Republic of Korea             9887        101           165
# 2              Australia             4707        348            20
# 3               Malaysia             2766        140            43
# 4                  Japan             2178        225            57
# ..                   ...              ...        ...           ...
# 200              Burundi                2          2             0
# 201         Sierra Leone                1          1             0
# 202              Réunion              247         40             0
# 203              Mayotte              101         19             0
# 204  conveyance (Diamond              712          0             7
#
#      New Deaths Transmission Classification  Days since last reported case
# 0             7          Local transmission                              0
# 1             3          Local transmission                              0
# 2             2          Local transmission                              0
# 3             6          Local transmission                              0
# 4             1          Local transmission                              0
# ..          ...                         ...                            ...
# 200           0         Imported cases only                              0
# 201           0         Imported cases only                              0
# 202           0          Local transmission                              0
# 203           0          Local transmission                              0
# 204           0          Local transmission                             16
#
# [205 rows x 7 columns]

# %%
df = df[df['Country/Territory'] != 'conveyance (Diamond']

# %%
death_rate = df['Total Deaths']/df['Total Confirmed']*100
df['Death Rate'] = death_rate
df
# Out:
# c:\users\ricardo_2\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 0                China            82631         86          3321           7
# 1    Republic of Korea             9887        101           165           3
# 2            Australia             4707        348            20           2
# 3             Malaysia             2766        140            43           6
# 4                Japan             2178        225            57           1
# ..                 ...              ...        ...           ...         ...
# 199            Liberia                3          0             0           0
# 200            Burundi                2          2             0           0
# 201       Sierra Leone                1          1             0           0
# 202            Réunion              247         40             0           0
# 203            Mayotte              101         19             0           0
#
#     Transmission Classification  Days since last reported case  Death Rate
# 0            Local transmission                              0    4.019073
# 1            Local transmission                              0    1.668858
# 2            Local transmission                              0    0.424899
# 3            Local transmission                              0    1.554591
# 4            Local transmission                              0    2.617080
# ..                          ...                            ...         ...
# 199          Local transmission                             10    0.000000
# 200         Imported cases only                              0    0.000000
# 201         Imported cases only                              0    0.000000
# 202          Local transmission                              0    0.000000
# 203          Local transmission                              0    0.000000
#
# [204 rows x 8 columns]

# %%
countries_infected = len(df)
print('The total number of countries infected is:',countries_infected)
# Out:
# The total number of countries infected is: 204

# %%
df = df.sort_values(by=['Death Rate'],ascending=False)

df[0:30]
# Out:
#                      Country/Territory  Total Confirmed  New Cases  \
# 198                             Gambia                3          0
# 190                             Angola                7          5
# 107                              Sudan                7          1
# 142                          Nicaragua                4          0
# 195                         Cabo Verde                5          0
# 106               Syrian Arab Republic               10          0
# 135                             Guyana               12          4
# 177                              Niger               20          0
# 192                              Gabon                7          0
# 189                           Zimbabwe                8          3
# 19                               Italy           105792       4053
# 152                       Saint Martin               18          0
# 83                          Bangladesh               54          5
# 62                          San Marino              236          6
# 154                            Curaçao               11          0
# 81                           Indonesia             1528        114
# 20                               Spain            94417       9222
# 153                     Cayman Islands               12          0
# 27                         Netherlands            12595        845
# 169                Democratic Republic              109         11
# 94                                Iraq              694         64
# 23                  The United Kingdom            25154       3009
# 22                              France            51477       7500
# 85                             Myanmar               15          5
# 89                                Iran            44606       3111
# 93                               Egypt              710         54
# 162                            Algeria              584         73
# 96                             Morocco              638         64
# 126  Bolivia (Plurinational\rState of)              107         10
# 26                             Belgium            12775        876
#
#      Total Deaths  New Deaths Transmission Classification  \
# 198             1           0         Imported cases only
# 190             2           2         Imported cases only
# 107             2           0         Imported cases only
# 142             1           0         Imported cases only
# 195             1           0         Imported cases only
# 106             2           0         Imported cases only
# 135             2           1          Local transmission
# 177             3           0          Local transmission
# 192             1           0         Imported cases only
# 189             1           0          Local transmission
# 19          12430         839          Local transmission
# 152             2           1         Under investigation
# 83              6           1          Local transmission
# 62             26           1          Local transmission
# 154             1           0         Imported cases only
# 81            136          14          Local transmission
# 20           8189         849          Local transmission
# 153             1           0         Imported cases only
# 27           1039         175          Local transmission
# 169             8           0          Local transmission
# 94             50           4          Local transmission
# 23           1789         381          Local transmission
# 22           3514         497          Local transmission
# 85              1           1          Local transmission
# 89           2898         141          Local transmission
# 93             46           5          Local transmission
# 162            35           4          Local transmission
# 96             36           3          Local transmission
# 126             6           1          Local transmission
# 26            705         192          Local transmission
#
#      Days since last reported case  Death Rate
# 198                              3   33.333333
# 190                              0   28.571429
# 107                              0   28.571429
# 142                              3   25.000000
# 195                              4   20.000000
# 106                              1   20.000000
# 135                              0   16.666667
# 177                              2   15.000000
# 192                              4   14.285714
# 189                              0   12.500000
# 19                               0   11.749471
# 152                              1   11.111111
# 83                               0   11.111111
# 62                               0   11.016949
# 154                              1    9.090909
# 81                               0    8.900524
# 20                               0    8.673226
# 153                              1    8.333333
# 27                               0    8.249305
# 169                              0    7.339450
# 94                               0    7.204611
# 23                               0    7.112189
# 22                               0    6.826350
# 85                               0    6.666667
# 89                               0    6.496884
# 93                               0    6.478873
# 162                              0    5.993151
# 96                               0    5.642633
# 126                              0    5.607477
# 26                               0    5.518591

# %%
minimum_number_cases = 1000 #define the minimum number of cases here/defina o número mínimo de casos aqui

dfMinNumCases = df[df['Total Confirmed'] > minimum_number_cases]
dfMinNumCases = dfMinNumCases.reset_index(drop=True)
dfMinNumCases.index = np.arange(1, (len(dfMinNumCases)+1))

dfMinNumCases[0:30]
# Out:
#            Country/Territory  Total Confirmed  New Cases  Total Deaths  \
# 1                      Italy           105792       4053         12430
# 2                  Indonesia             1528        114           136
# 3                      Spain            94417       9222          8189
# 4                Netherlands            12595        845          1039
# 5         The United Kingdom            25154       3009          1789
# 6                     France            51477       7500          3514
# 7                       Iran            44606       3111          2898
# 8                    Belgium            12775        876           705
# 9         Dominican Republic             1109        208            51
# 10               Philippines             2084        538            88
# 11                    Sweden             4435        407           180
# 12                     China            82631         86          3321
# 13                    Greece             1314        102            49
# 14                    Brazil             4579        323           159
# 15                   Ecuador             2240        278            75
# 16                   Denmark             2860        283            90
# 17                   Romania             2245        293            69
# 18                     Japan             2178        225            57
# 19                    Mexico             1094        101            28
# 20                     India             1636        565            38
# 21               Switzerland            16108        696           373
# 22                      Peru             1065        213            24
# 23                   Ireland             3235        325            71
# 24                  Portugal             7443       1035           160
# 25  United States of America           163199      22559          2850
# 26         Republic of Korea             9887        101           165
# 27                    Turkey            13531       2704           214
# 28                  Malaysia             2766        140            43
# 29                    Poland             2311        256            33
# 30                  Pakistan             2039        174            26
#
#     New Deaths Transmission Classification  Days since last reported case  \
# 1          839          Local transmission                              0
# 2           14          Local transmission                              0
# 3          849          Local transmission                              0
# 4          175          Local transmission                              0
# 5          381          Local transmission                              0
# 6          497          Local transmission                              0
# 7          141          Local transmission                              0
# 8          192          Local transmission                              0
# 9            9          Local transmission                              0
# 10          10          Local transmission                              0
# 11          34          Local transmission                              0
# 12           7          Local transmission                              0
# 13           6          Local transmission                              0
# 14          23          Local transmission                              0
# 15          15          Local transmission                              0
# 16          13          Local transmission                              0
# 17          25          Local transmission                              0
# 18           1          Local transmission                              0
# 19           8          Local transmission                              0
# 20           9          Local transmission                              0
# 21          78          Local transmission                              0
# 22          13          Local transmission                              0
# 23          17          Local transmission                              0
# 24          20          Local transmission                              0
# 25         452          Local transmission                              0
# 26           3          Local transmission                              0
# 27          46          Local transmission                              0
# 28           6          Local transmission                              0
# 29           2          Local transmission                              0
# 30           1          Local transmission                              0
#
#     Death Rate
# 1    11.749471
# 2     8.900524
# 3     8.673226
# 4     8.249305
# 5     7.112189
# 6     6.826350
# 7     6.496884
# 8     5.518591
# 9     4.598738
# 10    4.222649
# 11    4.058625
# 12    4.019073
# 13    3.729072
# 14    3.472374
# 15    3.348214
# 16    3.146853
# 17    3.073497
# 18    2.617080
# 19    2.559415
# 20    2.322738
# 21    2.315620
# 22    2.253521
# 23    2.194745
# 24    2.149671
# 25    1.746334
# 26    1.668858
# 27    1.581553
# 28    1.554591
# 29    1.427953
# 30    1.275135

# %%
#matplotlib defaults
sns.set(style="whitegrid")
top15_deathrate = dfMinNumCases[0:15]
death_rate = top15_deathrate.round({'Death Rate':2})
death_rate = death_rate['Death Rate']


plt.figure(figsize=(15,10))
plt.barh(top15_deathrate['Country/Territory'],top15_deathrate['Death Rate'],height=0.7, color='red')
plt.title('Death Rate per Country (01/04/2020)',fontsize=25)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Death Rate',y='Country/Territory', data=top15_deathrate ,
            label="Deaths", color="red")
plt.title('Death Rate per Country (01/04/2020)',fontsize=25)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)

for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('Graphs/20200401_DeathRatePerCountry.png', bbox_inches='tight')
plt.show()

# %%
#matplotlib defaults
top15_confirmed = top15_deathrate.sort_values(by=['Total Confirmed'],ascending=False)
countries = np.array(top15_confirmed['Country/Territory'])
confirmed = np.array(top15_confirmed['Total Confirmed'])
deaths = np.array(top15_confirmed['Total Deaths'])
diference = confirmed - deaths

plt.figure(figsize=(15,10))
p1 = plt.barh(countries,deaths, color='red')
p2 = plt.barh(countries,diference,left=deaths, color='yellow')
plt.title('Total Number of Cases/Deaths (01/04/2020)',fontsize=25)
plt.xlabel('Cases/Deaths',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.legend((p1[0], p2[0]), ('Deaths', 'Confirmed'), loc='lower right')
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 6))


sns.set_color_codes("pastel")
sns.barplot(x='Total Confirmed',y='Country/Territory', data=top15_confirmed,
            label="Confirmed", color="yellow")
sns.set_color_codes("muted")
sns.barplot(x='Total Deaths',y='Country/Territory', data=top15_confirmed ,
            label="Deaths", color="red")


plt.title('Total Number of Cases/Deaths in the Top15 Death Rate Countries (01/04/2020)',fontsize=18)
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Countries/Territory",
       xlabel="Cases/Deaths")
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
sns.despine(left=True, bottom=True)
plt.savefig('Graphs/20200401_TotalNumberCasesDeaths.png', bbox_inches='tight')

# %%
dfDSLRC = df.sort_values(by=['Days since last reported case'],ascending=False)#dfDSLRC = dataframe Days since last reported case
dfDSLRC[0:30]
# Out:
#                     Country/Territory  Total Confirmed  New Cases  \
# 144  Saint Vincent and the Grenadines                1          0
# 14                   Papua New Guinea                1          0
# 88                        Timor-Leste                1          0
# 199                           Liberia                3          0
# 13                               Fiji                5          0
# 160                          Anguilla                2          0
# 136                          Dominica               11          0
# 194                           Eritrea                6          0
# 157                        Montserrat                5          0
# 140                          Suriname                8          0
# 185                          Eswatini                9          0
# 193                   Central African                6          0
# 11                           Mongolia               12          0
# 192                             Gabon                7          0
# 195                        Cabo Verde                5          0
# 178                             Congo               19          0
# 141               Antigua and Barbuda                7          0
# 196                        Mauritania                5          0
# 187                        Mozambique                8          0
# 18                   Northern Mariana                2          0
# 180                              Mali               18          0
# 78                          Greenland               10          0
# 86                              Nepal                5          0
# 198                            Gambia                3          0
# 142                         Nicaragua                4          0
# 133                             Haiti               15          0
# 181                            Guinea               16          0
# 175                            Uganda               33          0
# 75                             Jersey               63          0
# 71                           Holy See                6          0
#
#      Total Deaths  New Deaths Transmission Classification  \
# 144             0           0         Imported cases only
# 14              0           0         Imported cases only
# 88              0           0         Under investigation
# 199             0           0          Local transmission
# 13              0           0          Local transmission
# 160             0           0          Local transmission
# 136             0           0          Local transmission
# 194             0           0         Imported cases only
# 157             0           0         Imported cases only
# 140             0           0         Imported cases only
# 185             0           0         Imported cases only
# 193             0           0         Imported cases only
# 11              0           0         Imported cases only
# 192             1           0         Imported cases only
# 195             1           0         Imported cases only
# 178             0           0         Imported cases only
# 141             0           0         Imported cases only
# 196             0           0         Imported cases only
# 187             0           0          Local transmission
# 18              0           0         Under investigation
# 180             0           0          Local transmission
# 78              0           0         Under investigation
# 86              0           0         Imported cases only
# 198             1           0         Imported cases only
# 142             1           0         Imported cases only
# 133             0           0         Imported cases only
# 181             0           0          Local transmission
# 175             0           0          Local transmission
# 75              2           0          Local transmission
# 71              0           0         Under investigation
#
#      Days since last reported case  Death Rate
# 144                             19    0.000000
# 14                              11    0.000000
# 88                              11    0.000000
# 199                             10    0.000000
# 13                               6    0.000000
# 160                              5    0.000000
# 136                              5    0.000000
# 194                              5    0.000000
# 157                              4    0.000000
# 140                              4    0.000000
# 185                              4    0.000000
# 193                              4    0.000000
# 11                               4    0.000000
# 192                              4   14.285714
# 195                              4   20.000000
# 178                              4    0.000000
# 141                              4    0.000000
# 196                              3    0.000000
# 187                              3    0.000000
# 18                               3    0.000000
# 180                              3    0.000000
# 78                               3    0.000000
# 86                               3    0.000000
# 198                              3   33.333333
# 142                              3   25.000000
# 133                              2    0.000000
# 181                              2    0.000000
# 175                              2    0.000000
# 75                               2    3.174603
# 71                               2    0.000000

# %%
#seaborn defaults
top15DSLRC = dfDSLRC[0:15].sort_values(by=['Days since last reported case'])
DSLRC = top15DSLRC['Days since last reported case']

f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Country/Territory',y='Days since last reported case', data=top15DSLRC ,
            label="Days since last reported case", color="blue")
plt.title('Days since Last Reported Case per Country (01/04/2020)',fontsize=24)
plt.ylabel('Days since last reported case',fontsize=18)
plt.xlabel('Countries/Territory',fontsize=18)
plt.xticks(rotation='vertical')
for i in range (0,15):
    plt.text(x=i, y=DSLRC.iloc[i]+0.4 , s=DSLRC.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('Graphs/20200401_DaysSinceLast.png', bbox_inches='tight')
plt.show()

# %%
#seaborn defaults
confirmedDSLRC = np.array(top15DSLRC['Total Confirmed'])
deathsDSLRC = np.array(top15DSLRC['Total Deaths'])
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 6))


sns.set_color_codes("pastel")
sns.barplot(x='Total Confirmed',y='Country/Territory', data=top15DSLRC,
            label="Confirmed", color="yellow")
sns.set_color_codes("muted")
sns.barplot(x='Total Deaths',y='Country/Territory', data=top15DSLRC ,
            label="Deaths", color="red")


plt.title('Total Number of Cases/Deaths in the Top15 Days Since Last Reported Case Countries (01/04/2020)',fontsize=18)
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Countries/Territory",
       xlabel="Cases/Deaths")
for i in range (0,15):
    plt.text(x=deathsDSLRC[i]+0.2, y=i , s=deathsDSLRC[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmedDSLRC[i]+0.4, y=i , s=confirmedDSLRC[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
sns.despine(left=True, bottom=True)
plt.savefig('Graphs/20200401_TotalNumberCasesDeathsDSLRC.png', bbox_inches='tight')

# %%
Transmission_type = pd.get_dummies(df, columns=['Transmission Classification'])
Transmission_type
# Out:
#                     Country/Territory  Total Confirmed  New Cases  \
# 198                            Gambia                3          0
# 190                            Angola                7          5
# 107                             Sudan                7          1
# 142                         Nicaragua                4          0
# 195                        Cabo Verde                5          0
# ..                                ...              ...        ...
# 69                      Liechtenstein               68          4
# 144  Saint Vincent and the Grenadines                1          0
# 143                            Belize                3          0
# 70                             Monaco               52          3
# 203                           Mayotte              101         19
#
#      Total Deaths  New Deaths  Days since last reported case  Death Rate  \
# 198             1           0                              3   33.333333
# 190             2           2                              0   28.571429
# 107             2           0                              0   28.571429
# 142             1           0                              3   25.000000
# 195             1           0                              4   20.000000
# ..            ...         ...                            ...         ...
# 69              0           0                              0    0.000000
# 144             0           0                             19    0.000000
# 143             0           0                              1    0.000000
# 70              0           0                              0    0.000000
# 203             0           0                              0    0.000000
#
#      Transmission Classification_Imported cases only  \
# 198                                                1
# 190                                                1
# 107                                                1
# 142                                                1
# 195                                                1
# ..                                               ...
# 69                                                 0
# 144                                                1
# 143                                                0
# 70                                                 0
# 203                                                0
#
#      Transmission Classification_Local transmission  \
# 198                                               0
# 190                                               0
# 107                                               0
# 142                                               0
# 195                                               0
# ..                                              ...
# 69                                                0
# 144                                               0
# 143                                               1
# 70                                                1
# 203                                               1
#
#      Transmission Classification_Under investigation
# 198                                                0
# 190                                                0
# 107                                                0
# 142                                                0
# 195                                                0
# ..                                               ...
# 69                                                 1
# 144                                                0
# 143                                                0
# 70                                                 0
# 203                                                0
#
# [204 rows x 10 columns]

# %%
print('The number of countries with only imported cases is:',Transmission_type['Transmission Classification_Imported cases only'].sum())
# Out:
# The number of countries with only imported cases is: 35

# %%
print('The number of countries with local transmissions cases is:',Transmission_type['Transmission Classification_Local transmission'].sum())
# Out:
# The number of countries with local transmissions cases is: 161

# %%
print('The number of countries under investigation to determine the type of transmission is:',Transmission_type['Transmission Classification_Under investigation'].sum())
# Out:
# The number of countries under investigation to determine the type of transmission is: 8
