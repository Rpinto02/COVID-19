# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Data/20200329-WHO.csv')
df
# Out:
#        Country/Territory  Total Confirmed  New Cases  Total Deaths  \
# 0                  China            82341        128          3306
# 1      Republic of Korea             9583        105           152
# 2              Australia             3966        331            16
# 3               Malaysia             2320        159            27
# 4                  Japan             1693        194            52
# ..                   ...              ...        ...           ...
# 196               Angola                2          0             0
# 197        Guinea-Bissau                2          0             0
# 198              Réunion              143          8             0
# 199              Mayotte               50          0             0
# 200  conveyance (Diamond              712          0             7
#
#      New Deaths Transmission Classification  Days since last reported case
# 0             5          Local transmission                              0
# 1             8          Local transmission                              0
# 2             2          Local transmission                              0
# 3             1          Local transmission                              0
# 4             3          Local transmission                              0
# ..          ...                         ...                            ...
# 196           0         Imported cases only                              7
# 197           0         Imported cases only                              3
# 198           0          Local transmission                              0
# 199           0          Local transmission                              2
# 200           0          Local transmission                             13
#
# [201 rows x 7 columns]

# %%
df = df[df['Country/Territory'] != 'conveyance (Diamond']

# %%
death_rate = df['Total Deaths']/df['Total Confirmed']*100
df['Death Rate'] = death_rate
df
# Out:
# c:\users\ricardo_2\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 0                China            82341        128          3306           5
# 1    Republic of Korea             9583        105           152           8
# 2            Australia             3966        331            16           2
# 3             Malaysia             2320        159            27           1
# 4                Japan             1693        194            52           3
# ..                 ...              ...        ...           ...         ...
# 195            Liberia                3          0             0           0
# 196             Angola                2          0             0           0
# 197      Guinea-Bissau                2          0             0           0
# 198            Réunion              143          8             0           0
# 199            Mayotte               50          0             0           0
#
#     Transmission Classification  Days since last reported case  Death Rate
# 0            Local transmission                              0    4.015011
# 1            Local transmission                              0    1.586142
# 2            Local transmission                              0    0.403429
# 3            Local transmission                              0    1.163793
# 4            Local transmission                              0    3.071471
# ..                          ...                            ...         ...
# 195          Local transmission                              7    0.000000
# 196         Imported cases only                              7    0.000000
# 197         Imported cases only                              3    0.000000
# 198          Local transmission                              0    0.000000
# 199          Local transmission                              2    0.000000
#
# [200 rows x 8 columns]

# %%
countries_infected = len(df)
print('The total number of countries infected is:',countries_infected)
# Out:
# The total number of countries infected is: 200

# %%
df = df.sort_values(by=['Death Rate'],ascending=False)

df[0:30]
# Out:
#                      Country/Territory  Total Confirmed  New Cases  \
# 194                             Gambia                3          1
# 139                          Nicaragua                4          2
# 190                         Cabo Verde                5          0
# 138                             Guyana                5          0
# 193                           Zimbabwe                5          0
# 104                              Sudan                5          2
# 153                            Curaçao                7          0
# 184                              Gabon                7          0
# 152                     Cayman Islands                8          0
# 18                               Italy            92472       5974
# 82                          Bangladesh               48          0
# 180                              Niger               10          0
# 58                          San Marino              228          0
# 79                           Indonesia             1155        109
# 168  Democratic Republic of\rthe Congo               68         10
# 93                                Iraq              506         48
# 19                               Spain            72248       8189
# 88                                Iran            35408       3076
# 24                         Netherlands             9762       1159
# 161                            Algeria              409         42
# 5                          Philippines             1075        272
# 92                               Egypt              576         40
# 21                              France            37145       4603
# 22                  The United Kingdom            17093       2546
# 96                             Morocco              437         79
# 127                           Paraguay               56          4
# 59                             Albania              212         15
# 0                                China            82341        128
# 173                              Kenya               25          0
# 25                             Belgium             9134       1850
#
#      Total Deaths  New Deaths Transmission Classification  \
# 194             1           0         Imported cases only
# 139             1           0         Imported cases only
# 190             1           0         Imported cases only
# 138             1           0          Local transmission
# 193             1           0          Local transmission
# 104             1           0         Under investigation
# 153             1           0         Imported cases only
# 184             1           0         Imported cases only
# 152             1           0         Imported cases only
# 18          10023         887          Local transmission
# 82              5           0          Local transmission
# 180             1           0          Local transmission
# 58             22           1          Local transmission
# 79            102          15          Local transmission
# 168             6           2          Local transmission
# 93             42           2          Local transmission
# 19           5690         832          Local transmission
# 88           2517         139          Local transmission
# 24            639          93          Local transmission
# 161            26           1          Local transmission
# 5              68          14          Local transmission
# 92             36           6          Local transmission
# 21           2311         319          Local transmission
# 22           1019         260          Local transmission
# 96             26           3          Local transmission
# 127             3           0          Local transmission
# 59             10           1          Local transmission
# 0            3306           5          Local transmission
# 173             1           0          Local transmission
# 25            353          64          Local transmission
#
#      Days since last reported case  Death Rate
# 194                              0   33.333333
# 139                              0   25.000000
# 190                              1   20.000000
# 138                             10   20.000000
# 193                              1   20.000000
# 104                              0   20.000000
# 153                              2   14.285714
# 184                              1   14.285714
# 152                              3   12.500000
# 18                               0   10.838957
# 82                               2   10.416667
# 180                              2   10.000000
# 58                               1    9.649123
# 79                               0    8.831169
# 168                              0    8.823529
# 93                               0    8.300395
# 19                               0    7.875651
# 88                               0    7.108563
# 24                               0    6.545790
# 161                              0    6.356968
# 5                                0    6.325581
# 92                               0    6.250000
# 21                               0    6.221564
# 22                               0    5.961505
# 96                               0    5.949657
# 127                              0    5.357143
# 59                               0    4.716981
# 0                                0    4.015011
# 173                              4    4.000000
# 25                               0    3.864681

# %%
minimum_number_cases = 1000 #define the minimum number of cases here/defina o número mínimo de casos aqui

dfMinNumCases = df[df['Total Confirmed'] > minimum_number_cases]
dfMinNumCases = dfMinNumCases.reset_index(drop=True)
dfMinNumCases.index = np.arange(1, (len(dfMinNumCases)+1))

dfMinNumCases[0:30]
# Out:
#            Country/Territory  Total Confirmed  New Cases  Total Deaths  \
# 1                      Italy            92472       5974         10023
# 2                  Indonesia             1155        109           102
# 3                      Spain            72248       8189          5690
# 4                       Iran            35408       3076          2517
# 5                Netherlands             9762       1159           639
# 6                Philippines             1075        272            68
# 7                     France            37145       4603          2311
# 8         The United Kingdom            17093       2546          1019
# 9                      China            82341        128          3306
# 10                   Belgium             9134       1850           353
# 11                     Japan             1693        194            52
# 12                    Greece             1061         95            32
# 13                    Sweden             3447        401           102
# 14                   Denmark             2201        155            65
# 15                    Brazil             3417        502            92
# 16                   Ecuador             1823        228            48
# 17                   Romania             1452        160            29
# 18                  Portugal             5170        902           100
# 19               Switzerland            13152       1048           235
# 20  United States of America           103321      18093          1668
# 21         Republic of Korea             9583        105           152
# 22                   Ireland             2415        294            36
# 23                    Turkey             7402       1704           108
# 24                  Malaysia             2320        159            27
# 25                    Canada             4757        739            55
# 26                    Poland             1638        249            18
# 27                Luxembourg             1831        226            18
# 28                  Pakistan             1526        291            13
# 29                   Austria             8291        594            68
# 30                   Germany            52547       3965           389
#
#     New Deaths Transmission Classification  Days since last reported case  \
# 1          887          Local transmission                              0
# 2           15          Local transmission                              0
# 3          832          Local transmission                              0
# 4          139          Local transmission                              0
# 5           93          Local transmission                              0
# 6           14          Local transmission                              0
# 7          319          Local transmission                              0
# 8          260          Local transmission                              0
# 9            5          Local transmission                              0
# 10          64          Local transmission                              0
# 11           3          Local transmission                              0
# 12           4          Local transmission                              0
# 13          10          Local transmission                              0
# 14          13          Local transmission                              0
# 15          15          Local transmission                              0
# 16          12          Local transmission                              0
# 17           5          Local transmission                              0
# 18          24          Local transmission                              0
# 19          38          Local transmission                              0
# 20         425          Local transmission                              0
# 21           8          Local transmission                              0
# 22          14          Local transmission                              0
# 23          16          Local transmission                              0
# 24           1          Local transmission                              0
# 25          16          Local transmission                              0
# 26           2          Local transmission                              0
# 27           3          Local transmission                              0
# 28           4          Local transmission                              0
# 29           0          Local transmission                              0
# 30          64          Local transmission                              0
#
#     Death Rate
# 1    10.838957
# 2     8.831169
# 3     7.875651
# 4     7.108563
# 5     6.545790
# 6     6.325581
# 7     6.221564
# 8     5.961505
# 9     4.015011
# 10    3.864681
# 11    3.071471
# 12    3.016023
# 13    2.959095
# 14    2.953203
# 15    2.692420
# 16    2.633022
# 17    1.997245
# 18    1.934236
# 19    1.786800
# 20    1.614386
# 21    1.586142
# 22    1.490683
# 23    1.459065
# 24    1.163793
# 25    1.156191
# 26    1.098901
# 27    0.983069
# 28    0.851900
# 29    0.820166
# 30    0.740290

# %%
#matplotlib defaults
sns.set(style="whitegrid")
top15_deathrate = dfMinNumCases[0:15]
death_rate = top15_deathrate.round({'Death Rate':2})
death_rate = death_rate['Death Rate']


plt.figure(figsize=(15,10))
plt.barh(top15_deathrate['Country/Territory'],top15_deathrate['Death Rate'],height=0.7, color='red')
plt.title('Death Rate per Country (29/03/2020)',fontsize=25)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Death Rate',y='Country/Territory', data=top15_deathrate ,
            label="Deaths", color="red")
plt.title('Death Rate per Country (29/03/2020)',fontsize=25)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)

for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('Graphs/20200329_DeathRatePerCountry.png', bbox_inches='tight')
plt.show()

# %%
#matplotlib defaults
top15_confirmed = top15_deathrate.sort_values(by=['Total Confirmed'],ascending=False)
countries = np.array(top15_confirmed['Country/Territory'])
confirmed = np.array(top15_confirmed['Total Confirmed'])
deaths = np.array(top15_confirmed['Total Deaths'])
diference = confirmed - deaths

plt.figure(figsize=(15,10))
p1 = plt.barh(countries,deaths, color='red')
p2 = plt.barh(countries,diference,left=deaths, color='yellow')
plt.title('Total Number of Cases/Deaths (29/03/2020)',fontsize=25)
plt.xlabel('Cases/Deaths',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.legend((p1[0], p2[0]), ('Deaths', 'Confirmed'), loc='lower right')
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 6))


sns.set_color_codes("pastel")
sns.barplot(x='Total Confirmed',y='Country/Territory', data=top15_confirmed,
            label="Confirmed", color="yellow")
sns.set_color_codes("muted")
sns.barplot(x='Total Deaths',y='Country/Territory', data=top15_confirmed ,
            label="Deaths", color="red")


plt.title('Total Number of Cases/Deaths in the Top15 Death Rate Countries (29/03/2020)',fontsize=18)
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Countries/Territory",
       xlabel="Cases/Deaths")
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
sns.despine(left=True, bottom=True)
plt.savefig('Graphs/20200329_TotalNumberCasesDeaths.png', bbox_inches='tight')

# %%
dfDSLRC = df.sort_values(by=['Days since last reported case'],ascending=False)#dfDSLRC = dataframe Days since last reported case
dfDSLRC[0:30]
# Out:
#                     Country/Territory  Total Confirmed  New Cases  \
# 143  Saint Vincent and the Grenadines                1          0
# 138                            Guyana                5          0
# 87                        Timor-Leste                1          0
# 14                   Papua New Guinea                1          0
# 195                           Liberia                3          0
# 185                        Seychelles                7          0
# 188                 Equatorial Guinea                6          0
# 196                            Angola                2          0
# 69                             Monaco               19          0
# 150      United States Virgin Islands               17          0
# 140                       Saint Lucia                3          0
# 173                             Kenya               25          0
# 13                               Fiji                5          0
# 197                     Guinea-Bissau                2          0
# 178                            Uganda               14          0
# 142             Saint Kitts and Nevis                2          0
# 141                            Belize                2          0
# 70                           Holy See                4          0
# 134                             Haiti                8          0
# 162                      Burkina Faso              146          0
# 105              Syrian Arab Republic                5          0
# 152                    Cayman Islands                8          0
# 189                           Eritrea                6          0
# 146                       Puerto Rico               64          0
# 158            British Virgin Islands                2          0
# 159         Turks and Caicos\rIslands                2          0
# 86                             Bhutan                3          0
# 153                           Curaçao                7          0
# 169                           Nigeria               65          0
# 157                          Anguilla                2          0
#
#      Total Deaths  New Deaths Transmission Classification  \
# 143             0           0         Imported cases only
# 138             1           0          Local transmission
# 87              0           0         Under investigation
# 14              0           0         Imported cases only
# 195             0           0          Local transmission
# 185             0           0         Imported cases only
# 188             0           0         Imported cases only
# 196             0           0         Imported cases only
# 69              0           0          Local transmission
# 150             0           0         Imported cases only
# 140             0           0         Imported cases only
# 173             1           0          Local transmission
# 13              0           0          Local transmission
# 197             0           0         Imported cases only
# 178             0           0         Imported cases only
# 142             0           0         Imported cases only
# 141             0           0          Local transmission
# 70              0           0         Under investigation
# 134             0           0         Imported cases only
# 162             3           0          Local transmission
# 105             0           0         Imported cases only
# 152             1           0         Imported cases only
# 189             0           0         Imported cases only
# 146             2           0         Imported cases only
# 158             0           0         Imported cases only
# 159             0           0         Imported cases only
# 86              0           0         Imported cases only
# 153             1           0         Imported cases only
# 169             1           0          Local transmission
# 157             0           0          Local transmission
#
#      Days since last reported case  Death Rate
# 143                             16    0.000000
# 138                             10   20.000000
# 87                               8    0.000000
# 14                               8    0.000000
# 195                              7    0.000000
# 185                              7    0.000000
# 188                              7    0.000000
# 196                              7    0.000000
# 69                               6    0.000000
# 150                              5    0.000000
# 140                              5    0.000000
# 173                              4    4.000000
# 13                               3    0.000000
# 197                              3    0.000000
# 178                              3    0.000000
# 142                              3    0.000000
# 141                              3    0.000000
# 70                               3    0.000000
# 134                              3    0.000000
# 162                              3    2.054795
# 105                              3    0.000000
# 152                              3   12.500000
# 189                              2    0.000000
# 146                              2    3.125000
# 158                              2    0.000000
# 159                              2    0.000000
# 86                               2    0.000000
# 153                              2   14.285714
# 169                              2    1.538462
# 157                              2    0.000000

# %%
#seaborn defaults
top15DSLRC = dfDSLRC[0:15].sort_values(by=['Days since last reported case'])
DSLRC = top15DSLRC['Days since last reported case']

f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Country/Territory',y='Days since last reported case', data=top15DSLRC ,
            label="Days since last reported case", color="blue")
plt.title('Days since Last Reported Case per Country (29/03/2020)',fontsize=24)
plt.ylabel('Days since last reported case',fontsize=18)
plt.xlabel('Countries/Territory',fontsize=18)
plt.xticks(rotation='vertical')
for i in range (0,15):
    plt.text(x=i, y=DSLRC.iloc[i]+0.4 , s=DSLRC.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('Graphs/20200329_DaysSinceLast.png', bbox_inches='tight')
plt.show()

# %%
#seaborn defaults
confirmedDSLRC = np.array(top15DSLRC['Total Confirmed'])
deathsDSLRC = np.array(top15DSLRC['Total Deaths'])
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 6))


sns.set_color_codes("pastel")
sns.barplot(x='Total Confirmed',y='Country/Territory', data=top15DSLRC,
            label="Confirmed", color="yellow")
sns.set_color_codes("muted")
sns.barplot(x='Total Deaths',y='Country/Territory', data=top15DSLRC ,
            label="Deaths", color="red")


plt.title('Total Number of Cases/Deaths in the Top15 Days Since Last Reported Case Countries (29/03/2020)',fontsize=18)
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Countries/Territory",
       xlabel="Cases/Deaths")
for i in range (0,15):
    plt.text(x=deathsDSLRC[i]+0.2, y=i , s=deathsDSLRC[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmedDSLRC[i]+0.4, y=i , s=confirmedDSLRC[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
sns.despine(left=True, bottom=True)
plt.savefig('Graphs/20200329_TotalNumberCasesDeathsDSLRC.png', bbox_inches='tight')

# %%
Transmission_type = pd.get_dummies(df, columns=['Transmission Classification'])
Transmission_type
# Out:
#     Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 194            Gambia                3          1             1           0
# 139         Nicaragua                4          2             1           0
# 190        Cabo Verde                5          0             1           0
# 138            Guyana                5          0             1           0
# 193          Zimbabwe                5          0             1           0
# ..                ...              ...        ...           ...         ...
# 103          Djibouti               15          2             0           0
# 101              Oman              167         15             0           0
# 87        Timor-Leste                1          0             0           0
# 86             Bhutan                3          0             0           0
# 199           Mayotte               50          0             0           0
#
#      Days since last reported case  Death Rate  \
# 194                              0   33.333333
# 139                              0   25.000000
# 190                              1   20.000000
# 138                             10   20.000000
# 193                              1   20.000000
# ..                             ...         ...
# 103                              0    0.000000
# 101                              0    0.000000
# 87                               8    0.000000
# 86                               2    0.000000
# 199                              2    0.000000
#
#      Transmission Classification_Imported cases only  \
# 194                                                1
# 139                                                1
# 190                                                1
# 138                                                0
# 193                                                0
# ..                                               ...
# 103                                                0
# 101                                                0
# 87                                                 0
# 86                                                 1
# 199                                                0
#
#      Transmission Classification_Local transmission  \
# 194                                               0
# 139                                               0
# 190                                               0
# 138                                               1
# 193                                               1
# ..                                              ...
# 103                                               1
# 101                                               1
# 87                                                0
# 86                                                0
# 199                                               1
#
#      Transmission Classification_Under investigation
# 194                                                0
# 139                                                0
# 190                                                0
# 138                                                0
# 193                                                0
# ..                                               ...
# 103                                                0
# 101                                                0
# 87                                                 1
# 86                                                 0
# 199                                                0
#
# [200 rows x 10 columns]

# %%
print('The number of countries with only imported cases is:',Transmission_type['Transmission Classification_Imported cases only'].sum())
# Out:
# The number of countries with only imported cases is: 43

# %%
print('The number of countries with local transmissions cases is:',Transmission_type['Transmission Classification_Local transmission'].sum())
# Out:
# The number of countries with local transmissions cases is: 148

# %%
print('The number of countries under investigation to determine the type of transmission is:',Transmission_type['Transmission Classification_Under investigation'].sum())
# Out:
# The number of countries under investigation to determine the type of transmission is: 9
