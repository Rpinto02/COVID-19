# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Data/20200328-WHO.csv')
df
# Out:
#      Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 0                China            82230        152          3301           3
# 1    Republic of Korea             9478        146           144           5
# 2            Australia             3635        650            14           1
# 3             Malaysia             2161        130            26           3
# 4                Japan             1499        112            49           3
# ..                 ...              ...        ...           ...         ...
# 196             Gambia                2          0             1           1
# 197      Guinea-Bissau                2          0             0           0
# 198            Réunion              135          0             0           0
# 199            Mayotte               50          0             0           0
# 200         conveyance              712          0             7           0
#
#     Transmission Classification  Days since last reported case
# 0            Local transmission                              0
# 1            Local transmission                              0
# 2            Local transmission                              0
# 3            Local transmission                              0
# 4            Local transmission                              0
# ..                          ...                            ...
# 196         Imported cases only                              3
# 197         Imported cases only                              2
# 198          Local transmission                              1
# 199          Local transmission                              1
# 200          Local transmission                             12
#
# [201 rows x 7 columns]

# %%
df = df[df['Country/Territory'] != 'conveyance']

# %%
death_rate = df['Total Deaths']/df['Total Confirmed']*100
df['Death Rate'] = death_rate
df
# Out:
# c:\users\ricardo_2\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 0                China            82230        152          3301           3
# 1    Republic of Korea             9478        146           144           5
# 2            Australia             3635        650            14           1
# 3             Malaysia             2161        130            26           3
# 4                Japan             1499        112            49           3
# ..                 ...              ...        ...           ...         ...
# 195             Angola                2          0             0           0
# 196             Gambia                2          0             1           1
# 197      Guinea-Bissau                2          0             0           0
# 198            Réunion              135          0             0           0
# 199            Mayotte               50          0             0           0
#
#     Transmission Classification  Days since last reported case  Death Rate
# 0            Local transmission                              0    4.014350
# 1            Local transmission                              0    1.519308
# 2            Local transmission                              0    0.385144
# 3            Local transmission                              0    1.203147
# 4            Local transmission                              0    3.268846
# ..                          ...                            ...         ...
# 195         Imported cases only                              6    0.000000
# 196         Imported cases only                              3   50.000000
# 197         Imported cases only                              2    0.000000
# 198          Local transmission                              1    0.000000
# 199          Local transmission                              1    0.000000
#
# [200 rows x 8 columns]

# %%
countries_infected = len(df)
print('The total number of countries infected is:',countries_infected)
# Out:
# The total number of countries infected is: 200

# %%
df = df.sort_values(by=['Death Rate'],ascending=False)

df[0:30]
# Out:
#                      Country/Territory  Total Confirmed  New Cases  \
# 196                             Gambia                2          0
# 141                          Nicaragua                2          0
# 106                              Sudan                3          0
# 192                           Zimbabwe                5          2
# 190                         Cabo Verde                5          2
# 138                             Guyana                5          0
# 184                              Gabon                7          1
# 153                            Curaçao                7          0
# 152                     Cayman Islands                8          0
# 18                               Italy            86498       5959
# 82                          Bangladesh               48          0
# 179                              Niger               10          0
# 55                          San Marino              228         10
# 94                                Iraq              458         76
# 79                           Indonesia             1046        153
# 19                               Spain            64059       7871
# 88                                Iran            32332       2926
# 169  Democratic Republic\rof the Congo               58          4
# 161                            Algeria              367         62
# 5                          Philippines              803         96
# 97                             Morocco              358         83
# 24                         Netherlands             8603       1172
# 21                              France            32542       3756
# 127                           Paraguay               52         11
# 92                               Egypt              536         41
# 22                  The United Kingdom            14547       2885
# 59                             Albania              197         11
# 0                                China            82230        152
# 129                          Guatemala               25          1
# 172                              Kenya               25          0
#
#      Total Deaths  New Deaths Transmission Classification  \
# 196             1           1         Imported cases only
# 141             1           1         Imported cases only
# 106             1           0         Imported cases only
# 192             1           0          Local transmission
# 190             1           1         Imported cases only
# 138             1           0          Local transmission
# 184             1           0         Imported cases only
# 153             1           0         Imported cases only
# 152             1           0         Imported cases only
# 18           9136         971          Local transmission
# 82              5           0          Local transmission
# 179             1           0          Local transmission
# 55             21           0          Local transmission
# 94             40           4          Local transmission
# 79             87           9          Local transmission
# 19           4858         769          Local transmission
# 88           2378         144          Local transmission
# 169             4           0          Local transmission
# 161            25           4          Local transmission
# 5              54           9          Local transmission
# 97             23          13          Local transmission
# 24            546         112          Local transmission
# 21           1992         297          Local transmission
# 127             3           0          Local transmission
# 92             30           6          Local transmission
# 22            759         181          Local transmission
# 59              9           1          Local transmission
# 0            3301           3          Local transmission
# 129             1           0          Local transmission
# 172             1           0          Local transmission
#
#      Days since last reported case  Death Rate
# 196                              3   50.000000
# 141                              6   50.000000
# 106                              3   33.333333
# 192                              0   20.000000
# 190                              0   20.000000
# 138                              9   20.000000
# 184                              0   14.285714
# 153                              1   14.285714
# 152                              2   12.500000
# 18                               0   10.562094
# 82                               1   10.416667
# 179                              1   10.000000
# 55                               0    9.210526
# 94                               0    8.733624
# 79                               0    8.317400
# 19                               0    7.583634
# 88                               0    7.354942
# 169                              0    6.896552
# 161                              0    6.811989
# 5                                0    6.724782
# 97                               0    6.424581
# 24                               0    6.346623
# 21                               0    6.121320
# 127                              0    5.769231
# 92                               0    5.597015
# 22                               0    5.217571
# 59                               0    4.568528
# 0                                0    4.014350
# 129                              0    4.000000
# 172                              3    4.000000

# %%
minimum_number_cases = 1000 #define the minimum number of cases here/defina o número mínimo de casos aqui

dfMinNumCases = df[df['Total Confirmed'] > minimum_number_cases]
dfMinNumCases = dfMinNumCases.reset_index(drop=True)
dfMinNumCases.index = np.arange(1, (len(dfMinNumCases)+1))

dfMinNumCases[0:30]
# Out:
#            Country/Territory  Total Confirmed  New Cases  Total Deaths  \
# 1                      Italy            86498       5959          9136
# 2                  Indonesia             1046        153            87
# 3                      Spain            64059       7871          4858
# 4                       Iran            32332       2926          2378
# 5                Netherlands             8603       1172           546
# 6                     France            32542       3756          1992
# 7         The United Kingdom            14547       2885           759
# 8                      China            82230        152          3301
# 9                    Belgium             7284       1049           289
# 10                     Japan             1499        112            49
# 11                    Sweden             3046        240            92
# 12                    Brazil             2915        482            77
# 13                   Denmark             2046        169            52
# 14                   Ecuador             1595        384            36
# 15                   Romania             1292        263            24
# 16                  Portugal             4268        724            76
# 17               Switzerland            12104       1390           197
# 18                    Turkey             5698       2069            92
# 19         Republic of Korea             9478        146           144
# 20  United States of America            85228      16894          1243
# 21                  Malaysia             2161        130            26
# 22                    Poland             1389        168            16
# 23                   Ireland             2121        302            22
# 24                    Canada             4018        463            39
# 25                Luxembourg             1605        152            15
# 26                   Austria             7697        668            68
# 27                  Pakistan             1235        178             9
# 28                   Finland             1025         67             7
# 29                   Germany            48582       6294           325
# 30                    Norway             3581        425            16
#
#     New Deaths Transmission Classification  Days since last reported case  \
# 1          971          Local transmission                              0
# 2            9          Local transmission                              0
# 3          769          Local transmission                              0
# 4          144          Local transmission                              0
# 5          112          Local transmission                              0
# 6          297          Local transmission                              0
# 7          181          Local transmission                              0
# 8            3          Local transmission                              0
# 9           69          Local transmission                              0
# 10           3          Local transmission                              0
# 11          26          Local transmission                              0
# 12          20          Local transmission                              0
# 13          11          Local transmission                              0
# 14           7          Local transmission                              0
# 15           7          Local transmission                              0
# 16          16          Local transmission                              0
# 17          36          Local transmission                              0
# 18          17          Local transmission                              0
# 19           5          Local transmission                              0
# 20         252          Local transmission                              0
# 21           3          Local transmission                              0
# 22           0          Local transmission                              0
# 23           3          Local transmission                              0
# 24           4          Local transmission                              0
# 25           6          Local transmission                              0
# 26          16          Local transmission                              0
# 27           1          Local transmission                              0
# 28           3          Local transmission                              0
# 29          72          Local transmission                              0
# 30           2          Local transmission                              0
#
#     Death Rate
# 1    10.562094
# 2     8.317400
# 3     7.583634
# 4     7.354942
# 5     6.346623
# 6     6.121320
# 7     5.217571
# 8     4.014350
# 9     3.967600
# 10    3.268846
# 11    3.020355
# 12    2.641509
# 13    2.541544
# 14    2.257053
# 15    1.857585
# 16    1.780694
# 17    1.627561
# 18    1.614602
# 19    1.519308
# 20    1.458441
# 21    1.203147
# 22    1.151908
# 23    1.037247
# 24    0.970632
# 25    0.934579
# 26    0.883461
# 27    0.728745
# 28    0.682927
# 29    0.668972
# 30    0.446803

# %%
#matplotlib defaults
sns.set(style="whitegrid")
top15_deathrate = dfMinNumCases[0:15]
death_rate = top15_deathrate.round({'Death Rate':2})
death_rate = death_rate['Death Rate']


plt.figure(figsize=(15,10))
plt.barh(top15_deathrate['Country/Territory'],top15_deathrate['Death Rate'],height=0.7, color='red')
plt.title('Death Rate per Country (28/03/2020)',fontsize=28)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Death Rate',y='Country/Territory', data=top15_deathrate ,
            label="Deaths", color="red")
plt.title('Death Rate per Country (28/03/2020)',fontsize=28)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)

for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('Graphs/20200328_DeathRatePerCountry.png', bbox_inches='tight')
plt.show()

# %%
#matplotlib defaults
top15_confirmed = top15_deathrate.sort_values(by=['Total Confirmed'],ascending=False)
countries = np.array(top15_confirmed['Country/Territory'])
confirmed = np.array(top15_confirmed['Total Confirmed'])
deaths = np.array(top15_confirmed['Total Deaths'])
diference = confirmed - deaths

plt.figure(figsize=(15,10))
p1 = plt.barh(countries,deaths, color='red')
p2 = plt.barh(countries,diference,left=deaths, color='yellow')
plt.title('Total Number of Cases/Deaths (28/03/2020)',fontsize=28)
plt.xlabel('Cases/Deaths',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.legend((p1[0], p2[0]), ('Deaths', 'Confirmed'), loc='lower right')
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 6))


sns.set_color_codes("pastel")
sns.barplot(x='Total Confirmed',y='Country/Territory', data=top15_confirmed,
            label="Confirmed", color="yellow")
sns.set_color_codes("muted")
sns.barplot(x='Total Deaths',y='Country/Territory', data=top15_confirmed ,
            label="Deaths", color="red")


plt.title('Total Number of Cases/Deaths in the Top15 Death Rate Countries (28/03/2020)',fontsize=18)
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Countries/Territory",
       xlabel="Cases/Deaths")
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
sns.despine(left=True, bottom=True)
plt.savefig('Graphs/20200328_TotalNumberCasesDeaths.png', bbox_inches='tight')

# %%
dfDSLRC = df.sort_values(by=['Days since last reported case'],ascending=False)#dfDSLRC = dataframe Days since last reported case
dfDSLRC[0:30]
# Out:
#                     Country/Territory  Total Confirmed  New Cases  \
# 143  Saint Vincent and the Grenadines                1          0
# 83                           Maldives               13          0
# 138                            Guyana                5          0
# 14                   Papua New Guinea                1          0
# 87                        Timor-Leste                1          0
# 141                         Nicaragua                2          0
# 195                            Angola                2          0
# 193                           Liberia                3          0
# 188                 Equatorial Guinea                6          0
# 186                        Seychelles                7          0
# 69                             Monaco               19          0
# 139                       Saint Lucia                3          0
# 149      United States Virgin Islands               17          0
# 172                             Kenya               25          0
# 107                             Libya                1          0
# 196                            Gambia                2          0
# 106                             Sudan                3          0
# 142             Saint Kitts and Nevis                2          0
# 197                     Guinea-Bissau                2          0
# 134                             Haiti                8          0
# 86                              Nepal                3          0
# 152                    Cayman Islands                8          0
# 128                           Jamaica               26          0
# 177      United Republic of\rTanzania               13          0
# 140                            Belize                2          0
# 176                            Uganda               14          0
# 13                               Fiji                5          0
# 70                           Holy See                4          0
# 162                      Burkina Faso              146          0
# 104              Syrian Arab Republic                5          0
#
#      Total Deaths  New Deaths Transmission Classification  \
# 143             0           0         Imported cases only
# 83              0           0          Local transmission
# 138             1           0          Local transmission
# 14              0           0         Imported cases only
# 87              0           0         Imported cases only
# 141             1           1         Imported cases only
# 195             0           0         Imported cases only
# 193             0           0          Local transmission
# 188             0           0         Imported cases only
# 186             0           0         Imported cases only
# 69              0           0          Local transmission
# 139             0           0         Imported cases only
# 149             0           0         Imported cases only
# 172             1           0          Local transmission
# 107             0           0         Imported cases only
# 196             1           1         Imported cases only
# 106             1           0         Imported cases only
# 142             0           0         Imported cases only
# 197             0           0         Imported cases only
# 134             0           0         Imported cases only
# 86              0           0         Imported cases only
# 152             1           0         Imported cases only
# 128             1           0          Local transmission
# 177             0           0         Imported cases only
# 140             0           0          Local transmission
# 176             0           0         Imported cases only
# 13              0           0          Local transmission
# 70              0           0         Under investigation
# 162             3           0          Local transmission
# 104             0           0         Imported cases only
#
#      Days since last reported case  Death Rate
# 143                             15    0.000000
# 83                              12    0.000000
# 138                              9   20.000000
# 14                               7    0.000000
# 87                               7    0.000000
# 141                              6   50.000000
# 195                              6    0.000000
# 193                              6    0.000000
# 188                              6    0.000000
# 186                              6    0.000000
# 69                               5    0.000000
# 139                              4    0.000000
# 149                              4    0.000000
# 172                              3    4.000000
# 107                              3    0.000000
# 196                              3   50.000000
# 106                              3   33.333333
# 142                              2    0.000000
# 197                              2    0.000000
# 134                              2    0.000000
# 86                               2    0.000000
# 152                              2   12.500000
# 128                              2    3.846154
# 177                              2    0.000000
# 140                              2    0.000000
# 176                              2    0.000000
# 13                               2    0.000000
# 70                               2    0.000000
# 162                              2    2.054795
# 104                              2    0.000000

# %%
#seaborn defaults
top15DSLRC = dfDSLRC[0:15].sort_values(by=['Days since last reported case'])
DSLRC = top15DSLRC['Days since last reported case']

f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Country/Territory',y='Days since last reported case', data=top15DSLRC ,
            label="Days since last reported case", color="blue")
plt.title('Days since Last Reported Case per Country (28/03/2020)',fontsize=24)
plt.ylabel('Days since last reported case',fontsize=18)
plt.xlabel('Countries/Territory',fontsize=18)
plt.xticks(rotation='vertical')
for i in range (0,15):
    plt.text(x=i, y=DSLRC.iloc[i]+0.4 , s=DSLRC.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('Graphs/20200328_DaysSinceLast.png', bbox_inches='tight')
plt.show()

# %%
#seaborn defaults
confirmedDSLRC = np.array(top15DSLRC['Total Confirmed'])
deathsDSLRC = np.array(top15DSLRC['Total Deaths'])
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 6))


sns.set_color_codes("pastel")
sns.barplot(x='Total Confirmed',y='Country/Territory', data=top15DSLRC,
            label="Confirmed", color="yellow")
sns.set_color_codes("muted")
sns.barplot(x='Total Deaths',y='Country/Territory', data=top15DSLRC ,
            label="Deaths", color="red")


plt.title('Total Number of Cases/Deaths in the Top15 Days Since Last Reported Case Countries (28/03/2020)',fontsize=18)
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Countries/Territory",
       xlabel="Cases/Deaths")
for i in range (0,15):
    plt.text(x=deathsDSLRC[i]+0.2, y=i , s=deathsDSLRC[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmedDSLRC[i]+0.4, y=i , s=confirmedDSLRC[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
sns.despine(left=True, bottom=True)
plt.savefig('Graphs/20200328_TotalNumberCasesDeathsDSLRC.png', bbox_inches='tight')

# %%
Transmission_type = pd.get_dummies(df, columns=['Transmission Classification'])
Transmission_type
# Out:
#     Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 196            Gambia                2          0             1           1
# 141         Nicaragua                2          0             1           1
# 106             Sudan                3          0             1           0
# 192          Zimbabwe                5          2             1           0
# 190        Cabo Verde                5          2             1           1
# ..                ...              ...        ...           ...         ...
# 131       El Salvador               13          0             0           0
# 130          Barbados               24          6             0           0
# 64            Belarus               94          8             0           0
# 65            Georgia               85          4             0           0
# 199           Mayotte               50          0             0           0
#
#      Days since last reported case  Death Rate  \
# 196                              3   50.000000
# 141                              6   50.000000
# 106                              3   33.333333
# 192                              0   20.000000
# 190                              0   20.000000
# ..                             ...         ...
# 131                              2    0.000000
# 130                              0    0.000000
# 64                               0    0.000000
# 65                               0    0.000000
# 199                              1    0.000000
#
#      Transmission Classification_Imported cases only  \
# 196                                                1
# 141                                                1
# 106                                                1
# 192                                                0
# 190                                                1
# ..                                               ...
# 131                                                1
# 130                                                0
# 64                                                 0
# 65                                                 0
# 199                                                0
#
#      Transmission Classification_Local transmission  \
# 196                                               0
# 141                                               0
# 106                                               0
# 192                                               1
# 190                                               0
# ..                                              ...
# 131                                               0
# 130                                               1
# 64                                                1
# 65                                                1
# 199                                               1
#
#      Transmission Classification_Under investigation
# 196                                                0
# 141                                                0
# 106                                                0
# 192                                                0
# 190                                                0
# ..                                               ...
# 131                                                0
# 130                                                0
# 64                                                 0
# 65                                                 0
# 199                                                0
#
# [200 rows x 10 columns]

# %%
print('The number of countries with only imported cases is:',Transmission_type['Transmission Classification_Imported cases only'].sum())
# Out:
# The number of countries with only imported cases is: 52

# %%
print('The number of countries with local transmissions cases is:',Transmission_type['Transmission Classification_Local transmission'].sum())
# Out:
# The number of countries with local transmissions cases is: 144

# %%
print('The number of countries under investigation to determine the type of transmission is:',Transmission_type['Transmission Classification_Under investigation'].sum())
# Out:
# The number of countries under investigation to determine the type of transmission is: 4
