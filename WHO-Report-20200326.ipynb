# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Data\20200326-WHO.csv')
df
# Out:
#      Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 0                China            81961        113          3293           6
# 1    Republic of Korea             9241        104           131           5
# 2            Australia             2799        547            11           3
# 3             Malaysia             1796        172            19           3
# 4                Japan             1291         98            45           2
# ..                 ...              ...        ...           ...         ...
# 193              Niger                2          0             0           0
# 194           Zimbabwe                2          0             1           0
# 195            Réunion               94         11             0           0
# 196            Mayotte               35          5             0           0
# 197         conveyance              712          0             7           0
#
#     Transmission Classification  Days since last reported case
# 0            Local transmission                              0
# 1            Local transmission                              0
# 2            Local transmission                              0
# 3            Local transmission                              0
# 4            Local transmission                              0
# ..                          ...                            ...
# 193         Imported cases only                              2
# 194         Imported cases only                              4
# 195          Local transmission                              0
# 196          Local transmission                              0
# 197          Local transmission                             10
#
# [198 rows x 7 columns]

# %%
death_rate = df['Total Deaths']/df['Total Confirmed']*100
df['Death Rate'] = death_rate
df
# Out:
#      Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 0                China            81961        113          3293           6
# 1    Republic of Korea             9241        104           131           5
# 2            Australia             2799        547            11           3
# 3             Malaysia             1796        172            19           3
# 4                Japan             1291         98            45           2
# ..                 ...              ...        ...           ...         ...
# 193              Niger                2          0             0           0
# 194           Zimbabwe                2          0             1           0
# 195            Réunion               94         11             0           0
# 196            Mayotte               35          5             0           0
# 197         conveyance              712          0             7           0
#
#     Transmission Classification  Days since last reported case  Death Rate
# 0            Local transmission                              0    4.017765
# 1            Local transmission                              0    1.417595
# 2            Local transmission                              0    0.392997
# 3            Local transmission                              0    1.057906
# 4            Local transmission                              0    3.485670
# ..                          ...                            ...         ...
# 193         Imported cases only                              2    0.000000
# 194         Imported cases only                              4   50.000000
# 195          Local transmission                              0    0.000000
# 196          Local transmission                              0    0.000000
# 197          Local transmission                             10    0.983146
#
# [198 rows x 8 columns]

# %%
countries_infected = len(df)-1#minus 1 due the Diamond Princess cruiser/menos um devido ao cruzeiro Diamond Princess
print('The total number of countries infected is:',countries_infected)
# Out:
# The total number of countries infected is: 197

# %%
df = df.sort_values(by=['Death Rate'],ascending=False)

df[0:30]
# Out:
#                      Country/Territory  Total Confirmed  New Cases  \
# 194                           Zimbabwe                2          0
# 104                              Sudan                3          0
# 135                             Guyana                5          0
# 176                              Gabon                6          0
# 152                            Curaçao                6          0
# 150                     Cayman Islands                8          3
# 81                          Bangladesh               39          0
# 52                          San Marino              208         21
# 17                               Italy            74386       5210
# 93                                Iraq              346         30
# 87                                Iran            27017       2206
# 78                           Indonesia              790        104
# 125                           Paraguay               41         14
# 18                               Spain            47610       7937
# 158                            Algeria              264          0
# 5                          Philippines              636         84
# 164  Democratic Republic\rof the Congo               51          6
# 23                         Netherlands             6412        852
# 20                              France            24920       2895
# 22                  The United Kingdom             9533       1452
# 91                               Egypt              456         54
# 165                          Mauritius               47          5
# 128                          Guatemala               24          3
# 0                                China            81961        113
# 145                        Puerto Rico               51         12
# 127                            Jamaica               26          5
# 47                             Hungary              261         35
# 25                             Belgium             4937        668
# 4                                Japan             1291         98
# 56                             Ukraine              156         43
#
#      Total Deaths  New Deaths Transmission Classification  \
# 194             1           0         Imported cases only
# 104             1           0         Imported cases only
# 135             1           0          Local transmission
# 176             1           0         Imported cases only
# 152             1           0         Imported cases only
# 150             1           0         Imported cases only
# 81              4           0          Local transmission
# 52             21           0          Local transmission
# 17           7505         685          Local transmission
# 93             29           2          Local transmission
# 87           2077         143          Local transmission
# 78             58           3          Local transmission
# 125             3           1          Local transmission
# 18           3434         738          Local transmission
# 158            17           0          Local transmission
# 5              38           3          Local transmission
# 164             3           1          Local transmission
# 23            356          80          Local transmission
# 20           1331         231          Local transmission
# 22            463          41          Local transmission
# 91             21           1          Local transmission
# 165             2           0         Imported cases only
# 128             1           0          Local transmission
# 0            3293           6          Local transmission
# 145             2           0         Imported cases only
# 127             1           0          Local transmission
# 47             10           0          Local transmission
# 25            178          56          Local transmission
# 4              45           2          Local transmission
# 56              5           1          Local transmission
#
#      Days since last reported case  Death Rate
# 194                              4   50.000000
# 104                              1   33.333333
# 135                              7   20.000000
# 176                              3   16.666667
# 152                              1   16.666667
# 150                              0   12.500000
# 81                               1   10.256410
# 52                               0   10.096154
# 17                               0   10.089264
# 93                               0    8.381503
# 87                               0    7.687752
# 78                               0    7.341772
# 125                              0    7.317073
# 18                               0    7.212770
# 158                              1    6.439394
# 5                                0    5.974843
# 164                              0    5.882353
# 23                               0    5.552090
# 20                               0    5.341091
# 22                               0    4.856813
# 91                               0    4.605263
# 165                              0    4.255319
# 128                              0    4.166667
# 0                                0    4.017765
# 145                              0    3.921569
# 127                              0    3.846154
# 47                               0    3.831418
# 25                               0    3.605428
# 4                                0    3.485670
# 56                               0    3.205128

# %%
minimum_number_cases = 1000#define the minimum number of cases here/defina o número mínimo de casos aqui

dfMinNumCases = df[df['Total Confirmed'] > minimum_number_cases]
dfMinNumCases = df.reset_index(drop=True)
dfMinNumCases.index = np.arange(1, (len(df)+1))

dfMinNumCases[0:30]
# Out:
#                     Country/Territory  Total Confirmed  New Cases  \
# 1                            Zimbabwe                2          0
# 2                               Sudan                3          0
# 3                              Guyana                5          0
# 4                               Gabon                6          0
# 5                             Curaçao                6          0
# 6                      Cayman Islands                8          3
# 7                          Bangladesh               39          0
# 8                          San Marino              208         21
# 9                               Italy            74386       5210
# 10                               Iraq              346         30
# 11                               Iran            27017       2206
# 12                          Indonesia              790        104
# 13                           Paraguay               41         14
# 14                              Spain            47610       7937
# 15                            Algeria              264          0
# 16                        Philippines              636         84
# 17  Democratic Republic\rof the Congo               51          6
# 18                        Netherlands             6412        852
# 19                             France            24920       2895
# 20                 The United Kingdom             9533       1452
# 21                              Egypt              456         54
# 22                          Mauritius               47          5
# 23                          Guatemala               24          3
# 24                              China            81961        113
# 25                        Puerto Rico               51         12
# 26                            Jamaica               26          5
# 27                            Hungary              261         35
# 28                            Belgium             4937        668
# 29                              Japan             1291         98
# 30                            Ukraine              156         43
#
#     Total Deaths  New Deaths Transmission Classification  \
# 1              1           0         Imported cases only
# 2              1           0         Imported cases only
# 3              1           0          Local transmission
# 4              1           0         Imported cases only
# 5              1           0         Imported cases only
# 6              1           0         Imported cases only
# 7              4           0          Local transmission
# 8             21           0          Local transmission
# 9           7505         685          Local transmission
# 10            29           2          Local transmission
# 11          2077         143          Local transmission
# 12            58           3          Local transmission
# 13             3           1          Local transmission
# 14          3434         738          Local transmission
# 15            17           0          Local transmission
# 16            38           3          Local transmission
# 17             3           1          Local transmission
# 18           356          80          Local transmission
# 19          1331         231          Local transmission
# 20           463          41          Local transmission
# 21            21           1          Local transmission
# 22             2           0         Imported cases only
# 23             1           0          Local transmission
# 24          3293           6          Local transmission
# 25             2           0         Imported cases only
# 26             1           0          Local transmission
# 27            10           0          Local transmission
# 28           178          56          Local transmission
# 29            45           2          Local transmission
# 30             5           1          Local transmission
#
#     Days since last reported case  Death Rate
# 1                               4   50.000000
# 2                               1   33.333333
# 3                               7   20.000000
# 4                               3   16.666667
# 5                               1   16.666667
# 6                               0   12.500000
# 7                               1   10.256410
# 8                               0   10.096154
# 9                               0   10.089264
# 10                              0    8.381503
# 11                              0    7.687752
# 12                              0    7.341772
# 13                              0    7.317073
# 14                              0    7.212770
# 15                              1    6.439394
# 16                              0    5.974843
# 17                              0    5.882353
# 18                              0    5.552090
# 19                              0    5.341091
# 20                              0    4.856813
# 21                              0    4.605263
# 22                              0    4.255319
# 23                              0    4.166667
# 24                              0    4.017765
# 25                              0    3.921569
# 26                              0    3.846154
# 27                              0    3.831418
# 28                              0    3.605428
# 29                              0    3.485670
# 30                              0    3.205128

# %%
#matplotlib defaults
sns.set(style="whitegrid")
top15_deathrate = dfMinNumCases[0:15]
death_rate = top15_deathrate.round({'Death Rate':2})
death_rate = death_rate['Death Rate']


plt.figure(figsize=(15,10))
plt.barh(top15_deathrate['Country/Territory'],top15_deathrate['Death Rate'],height=0.7, color='red')
plt.title('Death Rate per Country (26/03/2020)',fontsize=26)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Death Rate',y='Country/Territory', data=top15_deathrate ,
            label="Deaths", color="red")
plt.title('Death Rate per Country (26/03/2020)',fontsize=26)
plt.xlabel('Death Rate [%]',fontsize=18)
plt.ylabel('Country',fontsize=18)

for i in range (0,15):
    plt.text(x=death_rate.iloc[i]+0.4, y=i , s=death_rate.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('20200326_DeathRatePerCountry.png', bbox_inches='tight')
plt.show()

# %%
#matplotlib defaults
top15_confirmed = top15_deathrate.sort_values(by=['Total Confirmed'],ascending=False)
countries = np.array(top15_confirmed['Country/Territory'])
confirmed = np.array(top15_confirmed['Total Confirmed'])
deaths = np.array(top15_confirmed['Total Deaths'])
diference = confirmed - deaths

plt.figure(figsize=(15,10))
p1 = plt.barh(countries,deaths, color='red')
p2 = plt.barh(countries,diference,left=deaths, color='yellow')
plt.title('Total Number of Cases/Deaths (26/03/2020)',fontsize=26)
plt.xlabel('Cases/Deaths',fontsize=18)
plt.ylabel('Country',fontsize=18)
plt.legend((p1[0], p2[0]), ('Deaths', 'Confirmed'), loc='lower right')
plt.gca().invert_yaxis()
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
plt.show()

# %%
#seaborn defaults
sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(15, 6))


sns.set_color_codes("pastel")
sns.barplot(x='Total Confirmed',y='Country/Territory', data=top15_confirmed,
            label="Confirmed", color="yellow")
sns.set_color_codes("muted")
sns.barplot(x='Total Deaths',y='Country/Territory', data=top15_confirmed ,
            label="Deaths", color="red")


plt.title('Total Number of Cases/Deaths in the Top15 Death Rate Countries (26/03/2020)',fontsize=18)
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Countries/Territory",
       xlabel="Cases/Deaths")
for i in range (0,15):
    plt.text(x=deaths[i]+1900, y=i , s=deaths[i],horizontalalignment='center',verticalalignment='center', color='red',fontsize=14)
    plt.text(x=confirmed[i]+4000, y=i , s=confirmed[i],horizontalalignment='center',verticalalignment='center', fontsize=14)
sns.despine(left=True, bottom=True)
plt.savefig('20200326_TotalNumberCasesDeaths.png', bbox_inches='tight')

# %%
dfDSLRC = df.sort_values(by=['Days since last reported case'],ascending=False)#dfDSLRC = dataframe Days since last reported case
dfDSLRC[0:30]
# Out:
#                     Country/Territory  Total Confirmed  New Cases  \
# 142  Saint Vincent and the Grenadines                1          0
# 197                        conveyance              712          0
# 82                           Maldives               13          0
# 153                  Saint Barthélemy                3          0
# 135                            Guyana                5          0
# 192                        Mauritania                2          0
# 85                             Bhutan                2          0
# 13                   Papua New Guinea                1          0
# 86                        Timor-Leste                1          0
# 194                          Zimbabwe                2          0
# 139                         Nicaragua                2          0
# 175                 Equatorial Guinea                6          0
# 181                             Congo                4          0
# 11                           Mongolia               10          0
# 186                           Liberia                3          0
# 188                            Angola                2          0
# 174                        Seychelles                7          0
# 176                             Gabon                6          0
# 183                          Eswatini                4          0
# 141                           Grenada                1          0
# 68                             Monaco               23          0
# 187                            Zambia                3          0
# 156         Turks and Caicos\rIslands                1          0
# 155                      Sint Maarten                2          0
# 162                          Cameroon               70          0
# 177                             Benin                5          0
# 137                       Saint Lucia                3          0
# 148      United States Virgin Islands               17          0
# 184                            Guinea                4          0
# 185                              Chad                3          0
#
#      Total Deaths  New Deaths Transmission Classification  \
# 142             0           0         Imported cases only
# 197             7           0          Local transmission
# 82              0           0          Local transmission
# 153             0           0         Under investigation
# 135             1           0          Local transmission
# 192             0           0         Imported cases only
# 85              0           0         Imported cases only
# 13              0           0         Imported cases only
# 86              0           0         Imported cases only
# 194             1           0         Imported cases only
# 139             0           0         Imported cases only
# 175             0           0         Imported cases only
# 181             0           0         Imported cases only
# 11              0           0         Imported cases only
# 186             0           0          Local transmission
# 188             0           0         Imported cases only
# 174             0           0         Imported cases only
# 176             1           0         Imported cases only
# 183             0           0         Imported cases only
# 141             0           0         Imported cases only
# 68              0           0          Local transmission
# 187             0           0         Imported cases only
# 156             0           0         Imported cases only
# 155             0           0         Imported cases only
# 162             1           0          Local transmission
# 177             0           0         Imported cases only
# 137             0           0         Imported cases only
# 148             0           0         Imported cases only
# 184             0           0         Imported cases only
# 185             0           0         Imported cases only
#
#      Days since last reported case  Death Rate
# 142                             13    0.000000
# 197                             10    0.983146
# 82                              10    0.000000
# 153                             10    0.000000
# 135                              7   20.000000
# 192                              7    0.000000
# 85                               6    0.000000
# 13                               5    0.000000
# 86                               5    0.000000
# 194                              4   50.000000
# 139                              4    0.000000
# 175                              4    0.000000
# 181                              4    0.000000
# 11                               4    0.000000
# 186                              4    0.000000
# 188                              4    0.000000
# 174                              4    0.000000
# 176                              3   16.666667
# 183                              3    0.000000
# 141                              3    0.000000
# 68                               3    0.000000
# 187                              3    0.000000
# 156                              2    0.000000
# 155                              2    0.000000
# 162                              2    1.428571
# 177                              2    0.000000
# 137                              2    0.000000
# 148                              2    0.000000
# 184                              2    0.000000
# 185                              2    0.000000

# %%
#seaborn defaults
top15DSLRC = dfDSLRC[0:15].sort_values(by=['Days since last reported case'])
DSLRC = top15DSLRC['Days since last reported case']

f, ax = plt.subplots(figsize=(15, 12))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
sns.barplot(x='Country/Territory',y='Days since last reported case', data=top15DSLRC ,
            label="Days since last reported case", color="blue")
plt.title('Days since Last Reported Case per Country (26/03/2020)',fontsize=26)
plt.ylabel('Days since last reported case',fontsize=18)
plt.xlabel('Country',fontsize=18)
plt.xticks(rotation='vertical')
for i in range (0,15):
    plt.text(x=i, y=DSLRC.iloc[i]+0.4 , s=DSLRC.iloc[i],horizontalalignment='center',verticalalignment='center', fontsize=16)
plt.savefig('20200326_DaysSinceLast.png', bbox_inches='tight')
plt.show()

# %%
Transmission_type = pd.get_dummies(df, columns=['Transmission Classification'])
Transmission_type
# Out:
#     Country/Territory  Total Confirmed  New Cases  Total Deaths  New Deaths  \
# 194          Zimbabwe                2          0             1           0
# 104             Sudan                3          0             1           0
# 135            Guyana                5          0             1           0
# 176             Gabon                6          0             1           0
# 152           Curaçao                6          0             1           0
# ..                ...              ...        ...           ...         ...
# 45            Armenia              290         25             0           0
# 49             Latvia              221         24             0           0
# 50           Slovakia              216         12             0           0
# 59              Malta              129          9             0           0
# 99             Jordan              172         19             0           0
#
#      Days since last reported case  Death Rate  \
# 194                              4   50.000000
# 104                              1   33.333333
# 135                              7   20.000000
# 176                              3   16.666667
# 152                              1   16.666667
# ..                             ...         ...
# 45                               0    0.000000
# 49                               0    0.000000
# 50                               0    0.000000
# 59                               0    0.000000
# 99                               0    0.000000
#
#      Transmission Classification_Imported cases only  \
# 194                                                1
# 104                                                1
# 135                                                0
# 176                                                1
# 152                                                1
# ..                                               ...
# 45                                                 0
# 49                                                 0
# 50                                                 0
# 59                                                 0
# 99                                                 0
#
#      Transmission Classification_Local transmission  \
# 194                                               0
# 104                                               0
# 135                                               1
# 176                                               0
# 152                                               0
# ..                                              ...
# 45                                                1
# 49                                                1
# 50                                                1
# 59                                                1
# 99                                                1
#
#      Transmission Classification_Under investigation
# 194                                                0
# 104                                                0
# 135                                                0
# 176                                                0
# 152                                                0
# ..                                               ...
# 45                                                 0
# 49                                                 0
# 50                                                 0
# 59                                                 0
# 99                                                 0
#
# [198 rows x 10 columns]

# %%
print('The number of countries with only imported cases is:',Transmission_type['Transmission Classification_Imported cases only'].sum())
# Out:
# The number of countries with only imported cases is: 59

# %%
print('The number of countries with local transmissions cases is:',Transmission_type['Transmission Classification_Local transmission'].sum())
# Out:
# The number of countries with local transmissions cases is: 135

# %%
print('The number of countries under investigation to determine the type of transmission is:',Transmission_type['Transmission Classification_Under investigation'].sum())
# Out:
# The number of countries under investigation to determine the type of transmission is: 4
